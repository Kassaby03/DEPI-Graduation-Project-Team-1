# %%
# !pip install "apache-airflow==3.1.0" --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-3.1.0/constraints-3.13.txt"

# %%
pip show apache-airflow
# Out:
# Name: apache-airflow
# Version: 3.1.0
# Summary: Programmatically author, schedule and monitor data pipelines
# Home-page: https://airflow.apache.org/
# Author:
# Author-email: Apache Software Foundation <dev@airflow.apache.org>
# License:
# Location: c:\Users\husse\AppData\Local\Programs\Python\Python313\Lib\site-packages
# Requires: apache-airflow-core, apache-airflow-task-sdk, natsort
# Required-by: apache-airflow-providers-common-compat, apache-airflow-providers-common-io, apache-airflow-providers-common-sql, apache-airflow-providers-smtp, apache-airflow-providers-standard
# Note: you may need to restart the kernel to use updated packages.

# %%
airflow db init
# Out:
#   Cell In[5], line 1
#     airflow db init
#             ^
# SyntaxError: invalid syntax
